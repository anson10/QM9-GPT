# %%
import torch  
import pandas as pd
import torch.nn.functional as F
import matplotlib.pyplot as plt # for making figures

# %%
df = pd.read_csv('../data/processed/qm9_clean.csv')
words = df['smiles'].astype('str').tolist()

# %%
chars = sorted(list(set(''.join(words))))
stoi = {s:i+1 for i,s in enumerate(chars)}
stoi['.'] = 0
itos = {i:s for s,i in stoi.items()}
vocab_size = len(itos)
print(itos)
print(vocab_size)
# Out:
# {1: '#', 2: '(', 3: ')', 4: '+', 5: '-', 6: '1', 7: '2', 8: '3', 9: '4', 10: '5', 11: '=', 12: 'C', 13: 'F', 14: 'H', 15: 'N', 16: 'O', 17: '[', 18: ']', 0: '.'}
# 19

# %%
import random
random.seed(42)
random.shuffle(words)

# %%
# build the dataset
block_size = 24 # context length: how many characters do we take to predict the next one?

def build_dataset(words):  
  X, Y = [], []
  
  for w in words:
    context = [0] * block_size
    for ch in w + '.':
      ix = stoi[ch]
      X.append(context)
      Y.append(ix)
      context = context[1:] + [ix] # crop and append

  X = torch.tensor(X)
  Y = torch.tensor(Y)
  print(X.shape, Y.shape)
  return X, Y

n1 = int(0.8*len(words))
n2 = int(0.9*len(words))
Xtr,  Ytr  = build_dataset(words[:n1])     
Xdev, Ydev = build_dataset(words[n1:n2])   
Xte,  Yte  = build_dataset(words[n2:])
# Out:
# torch.Size([1737037, 24]) torch.Size([1737037])
# torch.Size([217037, 24]) torch.Size([217037])
# torch.Size([217214, 24]) torch.Size([217214])

# %%
for x,y in zip(Xtr[:20], Ytr[:20]):
  print(''.join(itos[ix.item()] for ix in x), '-->', itos[y.item()])
# Out:
# ........................ --> C
# .......................C --> N
# ......................CN --> =
# .....................CN= --> C
# ....................CN=C --> (
# ...................CN=C( --> O
# ..................CN=C(O --> C
# .................CN=C(OC --> C
# ................CN=C(OCC --> =
# ...............CN=C(OCC= --> O
# ..............CN=C(OCC=O --> )
# .............CN=C(OCC=O) --> C
# ............CN=C(OCC=O)C --> #
# ...........CN=C(OCC=O)C# --> N
# ..........CN=C(OCC=O)C#N --> .
# ........................ --> C
# .......................C --> C
# ......................CC --> #
# .....................CC# --> C
# ....................CC#C --> C

# %%
class Linear:
  
  def __init__(self, fan_in, fan_out, bias=True):
    self.weight = torch.randn((fan_in, fan_out)) / fan_in**0.5 # note: kaiming init
    self.bias = torch.zeros(fan_out) if bias else None
  
  def __call__(self, x):
    self.out = x @ self.weight
    if self.bias is not None:
      self.out += self.bias
    return self.out
  
  def parameters(self):
    return [self.weight] + ([] if self.bias is None else [self.bias])
  
class BatchNorm1d:
  
    def __init__(self, dim, eps=1e-5, momentum=0.1):
      self.eps = eps
      self.momentum = momentum
      self.training = True
      # parameters (trained with backprop)
      self.gamma = torch.ones(dim)
      self.beta = torch.zeros(dim)
      # buffers (trained with a running 'momentum update')
      self.running_mean = torch.zeros(dim)
      self.running_var = torch.ones(dim)
    
    def __call__(self, x):
      # calculate the forward pass
      if self.training:
        if x.ndim == 2:
          dim = 0
        elif x.ndim == 3:
          dim = (0,1)
        xmean = x.mean(dim, keepdim=True) # batch mean
        xvar = x.var(dim, keepdim=True) # batch variance
      else:
        xmean = self.running_mean
        xvar = self.running_var
      xhat = (x - xmean) / torch.sqrt(xvar + self.eps) # normalize to unit variance
      self.out = self.gamma * xhat + self.beta
      # update the buffers
      if self.training:
        with torch.no_grad():
          self.running_mean = (1 - self.momentum) * self.running_mean + self.momentum * xmean
          self.running_var = (1 - self.momentum) * self.running_var + self.momentum * xvar
      return self.out
    
    def parameters(self):
      return [self.gamma, self.beta]

class Tanh:
  def __call__(self, x):
    self.out = torch.tanh(x)
    return self.out
  def parameters(self):
    return []


class Embedding:
  
  def __init__(self, num_embeddings, embedding_dim):
    self.weight = torch.randn((num_embeddings, embedding_dim))
    
  def __call__(self, IX):
    self.out = self.weight[IX]
    return self.out
  
  def parameters(self):
    return [self.weight]


class FlattenConsecutive:
  
  def __init__(self, n):
    self.n = n
    
  def __call__(self, x):
    B, T, C = x.shape
    x = x.view(B, T//self.n, C*self.n)
    if x.shape[1] == 1:
      x = x.squeeze(1)
    self.out = x
    return self.out
  
  def parameters(self):
    return []
  
class Sequential:
  
  def __init__(self, layers):
    self.layers = layers
  
  def __call__(self, x):
    for layer in self.layers:
      x = layer(x)
    self.out = x
    return self.out
  
  def parameters(self):
    # get parameters of all layers and stretch them out into one list
    return [p for layer in self.layers for p in layer.parameters()]
  
class Flatten:
  def __call__(self, x):
    self.out = x.view(x.shape[0], -1)
    return self.out
  
  def parameters(self):
    return []

# %%
n_embd = 24 # the dimensionality of the character embedding vectors
n_hidden = 512 # the number of neurons in the hidden layer of the MLP
model = Sequential([
  Embedding(vocab_size, n_embd),
  FlattenConsecutive(2), Linear(n_embd * 2, n_hidden, bias=False), BatchNorm1d(n_hidden), Tanh(),
  FlattenConsecutive(2), Linear(n_hidden*2, n_hidden, bias=False), BatchNorm1d(n_hidden), Tanh(),
  FlattenConsecutive(2), Linear(n_hidden*2, n_hidden, bias=False), BatchNorm1d(n_hidden), Tanh(),
  Linear(n_hidden, vocab_size),
])

# parameter init
with torch.no_grad():
  model.layers[-1].weight *= 0.1 # last layer make less confident

parameters = model.parameters()
print(sum(p.nelement() for p in parameters)) # number of parameters in total
for p in parameters:
  p.requires_grad = True
# Out:
# 1086427

# %%
max_steps = 200000
batch_size = 32
lossi = []

for i in range(max_steps):
  
  # minibatch construct
  ix = torch.randint(0, Xtr.shape[0], (batch_size,))
  Xb, Yb = Xtr[ix], Ytr[ix] # batch X,Y
  
  # forward pass
  logits = model(Xb)
  if logits.ndim == 3:
    logits = logits[:, -1, :]
  loss = F.cross_entropy(logits, Yb) # loss function
  
  # backward pass
  for p in parameters:
    p.grad = None
  loss.backward()
  
  # update: simple SGD
  lr = 0.1 if i < 150000 else 0.01 # step learning rate decay
  for p in parameters:
    p.data += -lr * p.grad

  # track stats
  if i % 10000 == 0: # print every once in a while
    print(f'{i:7d}/{max_steps:7d}: {loss.item():.4f}')
  lossi.append(loss.log10().item())
# Out:
#       0/ 200000: 2.9517
#   10000/ 200000: 0.9083
#   20000/ 200000: 0.9893
#   30000/ 200000: 1.4097
#   40000/ 200000: 0.6834
#   50000/ 200000: 1.1716
#   60000/ 200000: 1.2522
#   70000/ 200000: 1.2257
#   80000/ 200000: 1.6226
#   90000/ 200000: 1.3331
#  100000/ 200000: 1.1530
#  110000/ 200000: 1.2361
#  120000/ 200000: 1.1351
#  130000/ 200000: 0.9021
#  140000/ 200000: 1.3176
#  150000/ 200000: 0.9717
#  160000/ 200000: 0.8621
#  170000/ 200000: 1.0302
#  180000/ 200000: 0.9525
#  190000/ 200000: 0.8405

# %%
for layer in model.layers:
  layer.training = False

# %%
@torch.no_grad()
def split_loss(split):
    # Set to evaluation mode
    for layer in model.layers:
        if hasattr(layer, 'training'):
            layer.training = False
            
    x, y = {
        'train': (Xtr, Ytr),
        'val': (Xdev, Ydev),
        'test': (Xte, Yte),
    }[split]
    
    batch_size = 1024 # Small enough to not crash RAM
    losses = []
    
    for i in range(0, x.shape[0], batch_size):
        Xb, Yb = x[i:i+batch_size], y[i:i+batch_size]
        logits = model(Xb)
        if logits.ndim == 3:
            logits = logits[:, -1, :]
        loss = F.cross_entropy(logits, Yb.long())
        losses.append(loss.item())
    
    print(f'{split:5s} loss: {sum(losses)/len(losses):.4f}')

# Reset layers to training mode after eval if needed
def set_train_mode():
    for layer in model.layers:
        if hasattr(layer, 'training'):
            layer.training = True
            
split_loss('train')
split_loss('val')
# Out:
# train loss: 0.9399
# val   loss: 0.9468

# %%
# sample from the model
for _ in range(20):
    
    out = []
    context = [0] * block_size # initialize with all ...
    while True:
      # forward pass the neural net
      logits = model(torch.tensor([context]))
      if logits.ndim == 3:
          logits = logits[:, -1, :]
      probs = F.softmax(logits, dim=1)
      # print(logits.shape)
      # print(Yb.shape)
      
      # sample from the distribution
      ix = torch.multinomial(probs, num_samples=1).item()
      # shift the context window and track the samples
      context = context[1:] + [ix]
      out.append(ix)
      # if we sample the special '.' token, break
      if ix == 0:
        break
    
    print(''.join(itos[i] for i in out))
# Out:
# CC1OCOC1C1NCC1=NOC(=O)CO.
# C#CC1C2CCC3C2C13.
# CN1CC(C)C1(CC1)C1COC1.
# C#CCOC1COC2CC2C1.
# COC1CC2(CC3C1)C2(C)O.
# OC=NC1=O.
# N=C(CC=O)O1.
# OC12CC1C(C=O)N1CC2C([O-])=O.
# CC1OC(CO1)C#N.
# O=CC1CCC(O)C=C1C.
# OCC12CC3C4C3N1C24O.
# CCC(C#N)C12.
# CC1OC(C)C1=NC=COC1=O.
# CC1CC2(C)C(C)=O.
# CC1CC(C)CO1.
# CN(C=N)C(=O)C#C.
# CC1(C)OC(C1)C=O.
# O=CNC1=CON=C1N.
# CC12CC(C1)O2.
# CN1CC1C=CNC1=N.

# %%
for layer in model.layers:
    print(layer.__class__.__name__, ':', tuple(layer.out.shape))
# Out:
# Embedding : (1, 24, 24)
# FlattenConsecutive : (1, 12, 48)
# Linear : (1, 12, 512)
# BatchNorm1d : (1, 12, 512)
# Tanh : (1, 12, 512)
# FlattenConsecutive : (1, 6, 1024)
# Linear : (1, 6, 512)
# BatchNorm1d : (1, 6, 512)
# Tanh : (1, 6, 512)
# FlattenConsecutive : (1, 3, 1024)
# Linear : (1, 3, 512)
# BatchNorm1d : (1, 3, 512)
# Tanh : (1, 3, 512)
# Linear : (1, 3, 19)

# %%
#pip install rdkit

# %%
from rdkit import Chem
from rdkit.Chem import Draw

def validate_smiles(smiles_str):
    """
    Attempts to parse a SMILES string. 
    Returns the Molecule object if valid, None if invalid.
    """
    # Remove the trailing stop token '.' if it's there
    smiles_str = smiles_str.replace('.', '')
    
    # MolFromSmiles returns None if the string is chemically impossible
    mol = Chem.MolFromSmiles(smiles_str)
    
    if mol:
        try:
            # Performs valency and aromaticity checks
            Chem.SanitizeMol(mol)
            return mol
        except:
            return None
    return None

# %%
n_samples = 500
valid_molecules = []
generated_smiles = []

# 1. Generate samples from your model
for _ in range(n_samples):
    out = []
    context = [0] * block_size
    while True:
        logits = model(torch.tensor([context]))
        if logits.ndim == 3:
            logits = logits[:, -1, :]
        probs = F.softmax(logits, dim=1)
        ix = torch.multinomial(probs, num_samples=1).item()
        context = context[1:] + [ix]
        if ix == 0: break
        out.append(itos[ix])
    
    smiles = "".join(out)
    generated_smiles.append(smiles)
    
    # 2. Validate with RDKit
    mol = validate_smiles(smiles)
    if mol:
        valid_molecules.append(mol)

# 3. Calculate Results
validity_rate = (len(valid_molecules) / n_samples) * 100
print(f"Total Samples: {n_samples}")
print(f"Valid Molecules: {len(valid_molecules)}")
print(f"Validity Rate: {validity_rate:.2f}%")
# Out:
# [02:12:31] SMILES Parse Error: unclosed ring for input: 'CN1C2CC2(O)C13'
# [02:12:31] SMILES Parse Error: unclosed ring for input: 'CC1CCC1(O)C2NC2C1(C)C3O2'
# [02:12:31] SMILES Parse Error: unclosed ring for input: 'O=C1CNC=NC1(C)COC=N1'
# [02:12:31] SMILES Parse Error: unclosed ring for input: 'CC1(C)C2CC1(O)COC1CC1C'
# [02:12:31] SMILES Parse Error: unclosed ring for input: 'CN=COCCOCOC1CCC2C1'
# [02:12:32] SMILES Parse Error: unclosed ring for input: 'CC1(CC=O)C=O'
# [02:12:32] SMILES Parse Error: unclosed ring for input: 'O=CC1=CN=CC(F)=CC(=O)C1OC2C(O)CC12O'
# [02:12:32] SMILES Parse Error: unclosed ring for input: 'C1C2C=CC3C4C1C24C5'
# [02:12:32] SMILES Parse Error: unclosed ring for input: 'CC12OC3CCC13C24'
# [02:12:32] SMILES Parse Error: unclosed ring for input: 'OC1C2NC2C2OCC13'
# [02:12:32] SMILES Parse Error: unclosed ring for input: 'C#CC1OC(=N)C2'
# [02:12:32] SMILES Parse Error: unclosed ring for input: 'CC1C2CC(=O)C2CC12'
# [02:12:32] SMILES Parse Error: unclosed ring for input: 'C1C2CC1C21COCCC2=C1'
# [02:12:32] SMILES Parse Error: unclosed ring for input: 'CC1CC2CC1C(=O)C#C'
# [02:12:32] SMILES Parse Error: unclosed ring for input: 'NC(=O)N1'
# [02:12:32] SMILES Parse Error: unclosed ring for input: 'CC1(C)C2O'
# [02:12:32] SMILES Parse Error: unclosed ring for input: 'OCC12CC3CC(C1)C2C'
# [02:12:32] SMILES Parse Error: extra open parentheses while parsing: CC(CC(=O)O1
# [02:12:32] SMILES Parse Error: check for mistakes around position 3:
# [02:12:32] CC(CC(=O)O1
# [02:12:32] ~~^
# [02:12:32] SMILES Parse Error: Failed parsing SMILES 'CC(CC(=O)O1' for input: 'CC(CC(=O)O1'
# [02:12:32] SMILES Parse Error: unclosed ring for input: 'CC1CC1C1CCOC=O'
# [02:12:32] SMILES Parse Error: unclosed ring for input: 'CC12CC(C1)C1(C)OC1C1CC1'
# [02:12:32] SMILES Parse Error: unclosed ring for input: 'N=C1OCC(=O)C#CC'
# [02:12:32] SMILES Parse Error: unclosed ring for input: 'CC1COC2C1'
# [02:12:32] SMILES Parse Error: ring closure 2 duplicates bond between atom 1 and atom 9 for input: 'CC12C=CC33CCOC3C12'
# [02:12:32] SMILES Parse Error: unclosed ring for input: 'CCN1C2C3C2C1C3N4'
# [02:12:33] SMILES Parse Error: unclosed ring for input: 'CCCC1CCC(CC#C)C=C2'
# [02:12:33] SMILES Parse Error: unclosed ring for input: 'CC1=CC23C'
# [02:12:33] SMILES Parse Error: unclosed ring for input: 'CCC1(C)C#C'
# [02:12:33] SMILES Parse Error: unclosed ring for input: 'O=CC12C3NC1C(N)C#N'
# [02:12:33] SMILES Parse Error: unclosed ring for input: 'CN=C1CN=CCC1OC1=NC=C(O)C12'
# [02:12:33] SMILES Parse Error: unclosed ring for input: 'OCC1=CCCO'
# [02:12:33] SMILES Parse Error: unclosed ring for input: 'CCCC1C(C)C1(C)NC1C#C'
# [02:12:33] SMILES Parse Error: unclosed ring for input: 'CCC1CN1C(=O)CN2N=CN=C12'
# [02:12:33] SMILES Parse Error: unclosed ring for input: 'CC1(O)CC1CNC(=N)C=NO1'
# [02:12:33] SMILES Parse Error: unclosed ring for input: 'CC(=O)OC=C1C'
# [02:12:33] SMILES Parse Error: syntax error while parsing: =NOC(=O)C=C1
# [02:12:33] SMILES Parse Error: check for mistakes around position 1:
# [02:12:33] =NOC(=O)C=C1
# [02:12:33] ^
# [02:12:33] SMILES Parse Error: Failed parsing SMILES '=NOC(=O)C=C1' for input: '=NOC(=O)C=C1'
# [02:12:33] SMILES Parse Error: unclosed ring for input: 'O=C1CC2=C(C1)OC=NCC1=O'
# [02:12:33] SMILES Parse Error: unclosed ring for input: 'O=CC(=O)C1O'
# [02:12:33] SMILES Parse Error: unclosed ring for input: 'CC12CC1COCOCCO1'
# [02:12:33] SMILES Parse Error: unclosed ring for input: 'CC1C2C3C(CNC13)C24'
# [02:12:33] SMILES Parse Error: unclosed ring for input: 'NC1=C(O)C(O)C1=COC(=N)C12'
# [02:12:34] SMILES Parse Error: extra close parentheses while parsing: O=CC1[NH2+]CC([NH3+])C1C([O-])=O)C1=NOC=NC1CO
# [02:12:34] SMILES Parse Error: check for mistakes around position 33:
# [02:12:34] C([NH3+])C1C([O-])=O)C1=NOC=NC1CO
# [02:12:34] ~~~~~~~~~~~~~~~~~~~~^
# [02:12:34] SMILES Parse Error: Failed parsing SMILES 'O=CC1[NH2+]CC([NH3+])C1C([O-])=O)C1=NOC=NC1CO' for input: 'O=CC1[NH2+]CC([NH3+])C1C([O-])=O)C1=NOC=NC1CO'
# [02:12:34] SMILES Parse Error: ring closure 2 duplicates bond between atom 3 and atom 12 for input: 'N#CCC12OC3C4CC(CCN4)C12'
# [02:12:34] SMILES Parse Error: unclosed ring for input: 'CC(=O)C12'
# [02:12:34] SMILES Parse Error: unclosed ring for input: 'C1C2OC3=NNC1=NNC=C1'
# [02:12:34] SMILES Parse Error: unclosed ring for input: 'CCCCC1OCC1C1CC1O2'
# [02:12:34] SMILES Parse Error: unclosed ring for input: 'N#CC1C2NC23CC(O2)C3N1'
# [02:12:34] Explicit valence for atom # 3 N, 4, is greater than permitted
# [02:12:34] SMILES Parse Error: unclosed ring for input: 'CC1=COC(=O)C=C(C=O)C=O'
# [02:12:34] SMILES Parse Error: unclosed ring for input: 'CCC(C)(CC1)C=O'
# [02:12:34] SMILES Parse Error: duplicated ring closure 1 bonds atom 11 to itself for input: 'C1C2C1C1(O)COC1(C)COC11CC1'
# [02:12:34] SMILES Parse Error: unclosed ring for input: 'OC(CC1O)C=O'
# [02:12:35] SMILES Parse Error: unclosed ring for input: 'CCCOCC1=NO'
# [02:12:35] SMILES Parse Error: unclosed ring for input: 'CC(C)N12'
# [02:12:35] SMILES Parse Error: unclosed ring for input: 'OC1CC23COC3C1C23'
# [02:12:35] SMILES Parse Error: extra open parentheses while parsing: CC1(CC1(O)C24
# [02:12:35] SMILES Parse Error: check for mistakes around position 4:
# [02:12:35] CC1(CC1(O)C24
# [02:12:35] ~~~^
# [02:12:35] SMILES Parse Error: Failed parsing SMILES 'CC1(CC1(O)C24' for input: 'CC1(CC1(O)C24'
# [02:12:35] SMILES Parse Error: unclosed ring for input: 'O=CNC(=O)NC1'
# [02:12:35] SMILES Parse Error: unclosed ring for input: 'OCCOC1=CNC(=O)OCC#N'
# [02:12:35] SMILES Parse Error: unclosed ring for input: 'C1C2C3C4C1C23'
# [02:12:35] SMILES Parse Error: unclosed ring for input: 'CN1C=NC2=NON=C2N=CN=CC2=O'
# [02:12:35] SMILES Parse Error: unclosed ring for input: 'CC12C3C1C1(C)C2OC12'
# [02:12:35] SMILES Parse Error: ring closure 2 duplicates bond between atom 2 and atom 3 for input: 'C1CC2=C2OCC12C'
# [02:12:35] SMILES Parse Error: unclosed ring for input: 'COC(CCC=O)NC1C'
# [02:12:35] SMILES Parse Error: unclosed ring for input: 'C1C2OC3CC3(O)C1NC21'
# [02:12:35] SMILES Parse Error: unclosed ring for input: 'CCC1OC(C)C=O'
# [02:12:36] SMILES Parse Error: unclosed ring for input: 'CCOC1(C)C'
# [02:12:36] SMILES Parse Error: unclosed ring for input: 'CCN1N=CN=C1NN=C(C#C)N1CC23'
# [02:12:36] SMILES Parse Error: unclosed ring for input: 'O=C1CCN=COC(=O)CC12C'
# [02:12:36] SMILES Parse Error: ring closure 2 duplicates bond between atom 1 and atom 7 for input: 'CC12CC3(CCO3)C12'
# [02:12:36] SMILES Parse Error: unclosed ring for input: 'CCC1=NC=C(F)C(=O)C2'
# [02:12:36] SMILES Parse Error: unclosed ring for input: 'OCC(O)C1CC23O'
# [02:12:36] SMILES Parse Error: unclosed ring for input: 'CCC12CCC1CC1OCC1OCC#C'
# [02:12:36] SMILES Parse Error: extra close parentheses while parsing: C#CC1CC2CN2C1)C=O
# [02:12:36] SMILES Parse Error: check for mistakes around position 14:
# [02:12:36] C#CC1CC2CN2C1)C=O
# [02:12:36] ~~~~~~~~~~~~~^
# [02:12:36] SMILES Parse Error: Failed parsing SMILES 'C#CC1CC2CN2C1)C=O' for input: 'C#CC1CC2CN2C1)C=O'
# [02:12:36] SMILES Parse Error: unclosed ring for input: 'OC(CCCC1)C#N'
# [02:12:36] SMILES Parse Error: unclosed ring for input: 'NC(=N)OC(C#N)C1(N)C#N'
# [02:12:36] SMILES Parse Error: unclosed ring for input: 'CC12CC1(O)CC(=O)C#C'
# [02:12:36] SMILES Parse Error: unclosed ring for input: 'CC1(CO)C2CC12CC=CC13C'
# [02:12:36] SMILES Parse Error: unclosed ring for input: 'CC12COC3CC1C2(C)C'
# [02:12:37] Explicit valence for atom # 6 N, 5, is greater than permitted
# [02:12:37] SMILES Parse Error: unclosed ring for input: 'CC12NC1CC2OCC12C'
# [02:12:37] SMILES Parse Error: unclosed ring for input: 'COC12CC(O1)C1OCC1O'
# [02:12:37] SMILES Parse Error: unclosed ring for input: 'CCOC(=O)C2'
# [02:12:37] SMILES Parse Error: unclosed ring for input: 'C#CC12CC1NC21CC12CCC1OC2=N'
# [02:12:37] SMILES Parse Error: unclosed ring for input: 'CN1C=NC2C3OCC2C3C12'
# [02:12:37] SMILES Parse Error: unclosed ring for input: 'CC12CC1(O)CC1'
# [02:12:37] SMILES Parse Error: unclosed ring for input: 'O=C1CC(O1)C1OC21'
# [02:12:37] SMILES Parse Error: unclosed ring for input: 'CC1C(=O)O2'
# [02:12:38] SMILES Parse Error: extra open parentheses while parsing: C1NC1C12OC(C1CC2=C2CN=CO1
# [02:12:38] SMILES Parse Error: check for mistakes around position 11:
# [02:12:38] C1NC1C12OC(C1CC2=C2CN=CO1
# [02:12:38] ~~~~~~~~~~^
# [02:12:38] SMILES Parse Error: Failed parsing SMILES 'C1NC1C12OC(C1CC2=C2CN=CO1' for input: 'C1NC1C12OC(C1CC2=C2CN=CO1'
# [02:12:38] SMILES Parse Error: unclosed ring for input: 'CC(=O)C1O'
# [02:12:38] SMILES Parse Error: unclosed ring for input: 'CC1=C(O)C(=N)OC=N'
# [02:12:38] SMILES Parse Error: unclosed ring for input: 'N=C1OC2C3CC1C2C3COC1C23'
# [02:12:38] SMILES Parse Error: unclosed ring for input: 'CC1C2CCC=CC1=NC=C(O1)C#C'
# [02:12:38] SMILES Parse Error: unclosed ring for input: 'COC12CC(C#C)CC1C#C'
# [02:12:38] SMILES Parse Error: unclosed ring for input: 'CC1=CC2(C)CCC1CO1'
# [02:12:38] SMILES Parse Error: unclosed ring for input: 'NC(=O)C1'
# [02:12:38] SMILES Parse Error: unclosed ring for input: 'OCCC1(C)OC1CC1'
# [02:12:38] SMILES Parse Error: unclosed ring for input: 'CCC(CC#N)C1'
# [02:12:39] SMILES Parse Error: unclosed ring for input: 'O=C1NN=C2'
# [02:12:39] SMILES Parse Error: unclosed ring for input: 'OC12CC(CO=NN)C#N'
# [02:12:39] SMILES Parse Error: unclosed ring for input: 'OC12CC1CC1CC#C'
# [02:12:39] SMILES Parse Error: unclosed ring for input: 'CC1OCC2C3NC3C1C23'
# [02:12:39] SMILES Parse Error: unclosed ring for input: 'C1C2C=CCC(=O)C1(O)CC#N'
# [02:12:39] SMILES Parse Error: unclosed ring for input: 'COC(=O)C(O)C1=O'
# [02:12:39] SMILES Parse Error: unclosed ring for input: 'CN=C(C)N=CO1'
# [02:12:39] SMILES Parse Error: unclosed ring for input: 'OCC1C2C3CC2(CC13)C2'
# [02:12:39] SMILES Parse Error: unclosed ring for input: 'CN(C=N)C(=O)O1'
# [02:12:40] SMILES Parse Error: duplicated ring closure 1 bonds atom 13 to itself for input: 'CC12NC1CC21COCCC12CCC11CN1'
# [02:12:40] SMILES Parse Error: unclosed ring for input: 'C#CCC1NC1C(O)C2C#N'
# [02:12:40] SMILES Parse Error: unclosed ring for input: 'OC1CC=C(C)C1=NON=N1'
# [02:12:40] SMILES Parse Error: unclosed ring for input: 'COCC(=CN1)C#N'
# [02:12:40] SMILES Parse Error: unclosed ring for input: 'COC1OC(=O)N2'
# [02:12:40] SMILES Parse Error: unclosed ring for input: 'CC12CC3C(C13)N24'
# [02:12:40] SMILES Parse Error: unclosed ring for input: 'O=C1CC2COC(=N)CC(N)=O'
# [02:12:40] SMILES Parse Error: unclosed ring for input: 'CC1(O)C2C3CC1N(C)C1CC1'
# [02:12:40] SMILES Parse Error: unclosed ring for input: 'CN=C1ON=C(C)C12'
# [02:12:40] SMILES Parse Error: extra open parentheses while parsing: OC12C(OC1=CN=CC(C)C(=O)OC=N
# [02:12:40] SMILES Parse Error: check for mistakes around position 6:
# [02:12:40] OC12C(OC1=CN=CC(C)C(=O)OC=N
# [02:12:40] ~~~~~^
# [02:12:40] SMILES Parse Error: Failed parsing SMILES 'OC12C(OC1=CN=CC(C)C(=O)OC=N' for input: 'OC12C(OC1=CN=CC(C)C(=O)OC=N'
# [02:12:40] SMILES Parse Error: unclosed ring for input: 'CC(C)(C)C1'
# [02:12:40] SMILES Parse Error: unclosed ring for input: 'CC1C(=N)NC=O'
# [02:12:40] SMILES Parse Error: unclosed ring for input: 'COCCOCC1CC1CCC=C1C#N'
# [02:12:40] SMILES Parse Error: unclosed ring for input: 'O=COC1C=C2CN=CO2'
# [02:12:40] SMILES Parse Error: unclosed ring for input: 'CC1=NNC(=N1)C2O'
# [02:12:40] SMILES Parse Error: unclosed ring for input: 'CC(C=O)C2OC2C1=O'
# [02:12:41] SMILES Parse Error: unclosed ring for input: 'CC12OCC1N(=NO)C2OC12C=O'
# [02:12:41] SMILES Parse Error: unclosed ring for input: 'CN1CC1CC2OC=NC12C'
# [02:12:41] SMILES Parse Error: unclosed ring for input: 'CCC(=O)N1C'
# [02:12:41] SMILES Parse Error: unclosed ring for input: 'CC1(O)CC11COC1C2'
# [02:12:41] SMILES Parse Error: unclosed ring for input: 'CCC(C#N)C12'
# [02:12:41] SMILES Parse Error: unclosed ring for input: 'CC1C(C)O'
# [02:12:41] SMILES Parse Error: unclosed ring for input: 'CC(O)C(CO)=NO1'
# [02:12:41] SMILES Parse Error: unclosed ring for input: 'CC12COC3C(CC13)N24'
# [02:12:41] SMILES Parse Error: unclosed ring for input: 'CNC1=C(O)C(=O)C#C'
# [02:12:41] SMILES Parse Error: unclosed ring for input: 'CNC(CC=O)C1C#N'
# [02:12:41] SMILES Parse Error: unclosed ring for input: 'NC(=O)CC1'
# [02:12:41] SMILES Parse Error: extra close parentheses while parsing: CCCCOCC(C)C1CC2CC1C2)C#N
# [02:12:41] SMILES Parse Error: check for mistakes around position 21:
# [02:12:41] CCCCOCC(C)C1CC2CC1C2)C#N
# [02:12:41] ~~~~~~~~~~~~~~~~~~~~^
# [02:12:41] SMILES Parse Error: Failed parsing SMILES 'CCCCOCC(C)C1CC2CC1C2)C#N' for input: 'CCCCOCC(C)C1CC2CC1C2)C#N'
# [02:12:41] SMILES Parse Error: unclosed ring for input: 'OC12C3NC1C13C'
# [02:12:41] SMILES Parse Error: unclosed ring for input: 'OC1(CCCC1)O2'
# [02:12:41] SMILES Parse Error: unclosed ring for input: 'CCC1(CO1)C1=CNC=CC1=COC2=C1'
# [02:12:41] SMILES Parse Error: unclosed ring for input: 'CC12C3C1C1NC2C1'
# [02:12:41] SMILES Parse Error: unclosed ring for input: 'CC1C2CC=CCC1O'
# [02:12:42] SMILES Parse Error: unclosed ring for input: 'CCC(COC=N)CC=C1'
# [02:12:42] SMILES Parse Error: unclosed ring for input: 'OCC12CC1C1OCCC1=O'
# [02:12:42] SMILES Parse Error: unclosed ring for input: 'CN=C(N)C(=O)C1=NCCOC1=NNN=C1C'
# [02:12:42] SMILES Parse Error: unclosed ring for input: 'CC(=O)C1CC2OCC2COC1C2'
# [02:12:42] SMILES Parse Error: unclosed ring for input: 'CC#CC12OC3COC1(C)C2C3CC3C1=O'
# [02:12:42] SMILES Parse Error: unclosed ring for input: 'CC1CC(O)C2'
# [02:12:42] SMILES Parse Error: unclosed ring for input: 'COC1CC1(C)CO1'
# [02:12:42] SMILES Parse Error: unclosed ring for input: 'N#CC12CC1C1CCO1'
# [02:12:42] SMILES Parse Error: unclosed ring for input: 'CC1OC2(C)C13'
# [02:12:42] SMILES Parse Error: ring closure 2 duplicates bond between atom 1 and atom 6 for input: 'CC12CC3=C(OC123)C#N'
# [02:12:42] SMILES Parse Error: unclosed ring for input: 'CC12CCCC1(O)CC(O)C1C2(O)C=O'
# [02:12:42] SMILES Parse Error: unclosed ring for input: 'C1CC23CC1O2'
# [02:12:42] SMILES Parse Error: unclosed ring for input: 'NC1=CC(=O)COC(N)=O'
# [02:12:42] SMILES Parse Error: unclosed ring for input: 'CC#CC1NC2CC(=O)N1C2CC1C(=O)C2'
# [02:12:42] SMILES Parse Error: ring closure 2 duplicates bond between atom 1 and atom 6 for input: 'OC12CC3CC3C12'
# [02:12:42] SMILES Parse Error: unclosed ring for input: 'COC(=O)C2CN12'
# [02:12:43] SMILES Parse Error: unclosed ring for input: 'C1N2C3C4C(C3C1C23)C=O'
# [02:12:43] SMILES Parse Error: ring closure 2 duplicates bond between atom 2 and atom 8 for input: 'COC12CC3CC(C3)C12'
# [02:12:43] SMILES Parse Error: ring closure 2 duplicates bond between atom 1 and atom 5 for input: 'CC12CC(O)C12'
# [02:12:43] SMILES Parse Error: extra open parentheses while parsing: CC1(NC2COC12
# [02:12:43] SMILES Parse Error: check for mistakes around position 4:
# [02:12:43] CC1(NC2COC12
# [02:12:43] ~~~^
# [02:12:43] SMILES Parse Error: Failed parsing SMILES 'CC1(NC2COC12' for input: 'CC1(NC2COC12'
# [02:12:43] SMILES Parse Error: unclosed ring for input: 'COC1=CC(C)=NO'
# [02:12:43] SMILES Parse Error: unclosed ring for input: 'CC(=O)C12CCC1CC2NOC3=CCO1'
# [02:12:43] SMILES Parse Error: unclosed ring for input: 'CC1C2OC3C4C2CC1N24'
# [02:12:43] SMILES Parse Error: unclosed ring for input: 'NC1=CN2C=CC=CC2=O'
# [02:12:43] SMILES Parse Error: unclosed ring for input: 'CC12CC1(O)COC1(C)OC2(CN2)C=C1'
# [02:12:43] SMILES Parse Error: unclosed ring for input: 'CC(O)C(C1)C2'
# [02:12:43] SMILES Parse Error: unclosed ring for input: 'CCOC(=O)C(O)CC(O)C1=CC=NN1CCC1=O'
# [02:12:43] SMILES Parse Error: unclosed ring for input: 'CC(C)C(=O)C=C1N'
# [02:12:43] SMILES Parse Error: unclosed ring for input: 'CC1C(O)C2(O)CC11COC=NC1C#C'
# [02:12:43] SMILES Parse Error: unclosed ring for input: 'CCC(=O)C=CN1'
# [02:12:43] SMILES Parse Error: unclosed ring for input: 'CC1C(O)(CO)C13'
# [02:12:43] SMILES Parse Error: unclosed ring for input: 'CN1N=CC(=O)N#C'
# [02:12:43] SMILES Parse Error: unclosed ring for input: 'CC(=O)C1O'
# [02:12:43] SMILES Parse Error: unclosed ring for input: 'O=C1OC2CC2(C)C1(O)CC1C(C)C=O'
# [02:12:43] SMILES Parse Error: ring closure 2 duplicates bond between atom 1 and atom 7 for input: 'CC12CCC3OC3C12'
# [02:12:43] SMILES Parse Error: unclosed ring for input: 'CC12OC(=N)C1=NO'
# [02:12:43] SMILES Parse Error: unclosed ring for input: 'COC(C)OC=N1'
# [02:12:43] SMILES Parse Error: unclosed ring for input: 'NC1=C(CC#N)OC2'
# [02:12:43] SMILES Parse Error: unclosed ring for input: 'CC1(C)C2O'
# [02:12:44] SMILES Parse Error: unclosed ring for input: 'CN1CC2C1N2CC=C2'
# [02:12:44] SMILES Parse Error: unclosed ring for input: 'O=C1NCC(CNC2)O1'
# [02:12:44] SMILES Parse Error: unclosed ring for input: 'C#CC1CN=C(C)N1C=CN=C1F'
# [02:12:44] SMILES Parse Error: unclosed ring for input: 'CC12OCC1COC2CC12'
# [02:12:44] SMILES Parse Error: unclosed ring for input: 'OCCNC(C#C)C(C#N)N12'
# [02:12:44] SMILES Parse Error: unclosed ring for input: 'CC1=C(C)C(N)=O'
# [02:12:44] SMILES Parse Error: unclosed ring for input: 'CC1C(C)C(N2)C#N'
# [02:12:44] SMILES Parse Error: unclosed ring for input: 'C1C23COC12CC3(CC3)C1C23'
# [02:12:44] SMILES Parse Error: unclosed ring for input: 'CN1C=CC(C)C1=COC(O)=C1'
# [02:12:44] SMILES Parse Error: unclosed ring for input: 'CCCCC1NC1C1C2CC1C=C2OCCN12'
# [02:12:44] SMILES Parse Error: unclosed ring for input: 'CCC1COC(C)C12'
# [02:12:44] SMILES Parse Error: extra open parentheses while parsing: CC12CC(C1)(C[NH+]1C2NC1C2=O
# [02:12:44] SMILES Parse Error: check for mistakes around position 11:
# [02:12:44] CC12CC(C1)(C[NH+]1C2NC1C2=O
# [02:12:44] ~~~~~~~~~~^
# [02:12:44] SMILES Parse Error: Failed parsing SMILES 'CC12CC(C1)(C[NH+]1C2NC1C2=O' for input: 'CC12CC(C1)(C[NH+]1C2NC1C2=O'
# [02:12:44] SMILES Parse Error: unclosed ring for input: 'NC(C#N)C1N2C'
# [02:12:44] SMILES Parse Error: ring closure 2 duplicates bond between atom 1 and atom 5 for input: 'CC12CCC3N12'
# [02:12:44] SMILES Parse Error: unclosed ring for input: 'NC(=O)OC1(C)CC2(C)O'
# [02:12:44] SMILES Parse Error: unclosed ring for input: 'CNC1=CNC(=N)N(C)C=O'
# [02:12:44] SMILES Parse Error: unclosed ring for input: 'OCC1=CN2CC(=O)CCO'
# [02:12:44] SMILES Parse Error: unclosed ring for input: 'COC1=CN(C=O)C=O'
# [02:12:45] SMILES Parse Error: unclosed ring for input: 'NC1=C2C=O'
# [02:12:45] SMILES Parse Error: unclosed ring for input: 'CCC1=COC(=O)C1=COCO1'
# [02:12:45] SMILES Parse Error: unclosed ring for input: 'CC1C2CC2C11COCC1C2'
# [02:12:45] SMILES Parse Error: duplicated ring closure 1 bonds atom 8 to itself for input: 'OCC(=O)C(O)C2OC11CO1'
# [02:12:45] SMILES Parse Error: duplicated ring closure 1 bonds atom 7 to itself for input: 'O=CC12NC1C(O)C11CNC1=O'
# [02:12:45] SMILES Parse Error: unclosed ring for input: 'N=C1OCC=C1OCC=CCC123'
# [02:12:45] SMILES Parse Error: unclosed ring for input: 'OC12CC3CC=C1CC2(CO1)C=O'
# [02:12:45] SMILES Parse Error: unclosed ring for input: 'O=C1OC2C3CC2(OC)C2(C)CCC2OC2C1C#N'
# [02:12:45] SMILES Parse Error: unclosed ring for input: 'NC1=C2N=COC=NC1=NOC=N1'
# [02:12:45] SMILES Parse Error: unclosed ring for input: 'CNC1=CC(O)CC=O'
# [02:12:45] SMILES Parse Error: unclosed ring for input: 'CC(O)C(O)=N1'
# [02:12:45] SMILES Parse Error: unclosed ring for input: 'CCC12OC3'
# [02:12:45] SMILES Parse Error: unclosed ring for input: 'CC1N2C(C)C(C1)CC=NC'
# [02:12:45] SMILES Parse Error: unclosed ring for input: 'CCOC1CC(N)=O'
# [02:12:45] SMILES Parse Error: unclosed ring for input: 'N#CC12C3CN1C'
# [02:12:45] SMILES Parse Error: unclosed ring for input: 'CCCCC1CC1COC=N2'
# [02:12:45] SMILES Parse Error: unclosed ring for input: 'N=C#CC1CC11CC2C=C1CCCC1C#C'
# [02:12:46] SMILES Parse Error: unclosed ring for input: 'CNC(=O)C(N)=C1'
# [02:12:46] SMILES Parse Error: extra close parentheses while parsing: CC1=C(N)C(=O)C=O)C1CC2O1
# [02:12:46] SMILES Parse Error: check for mistakes around position 17:
# [02:12:46] CC1=C(N)C(=O)C=O)C1CC2O1
# [02:12:46] ~~~~~~~~~~~~~~~~^
# [02:12:46] SMILES Parse Error: Failed parsing SMILES 'CC1=C(N)C(=O)C=O)C1CC2O1' for input: 'CC1=C(N)C(=O)C=O)C1CC2O1'
# [02:12:46] SMILES Parse Error: unclosed ring for input: 'CC12CC(C1)C(CO)CO'
# [02:12:46] SMILES Parse Error: extra open parentheses while parsing: NC1(CCC1=CON=C1CN=CC=NC=N1
# [02:12:46] SMILES Parse Error: check for mistakes around position 4:
# [02:12:46] NC1(CCC1=CON=C1CN=CC=NC=N1
# [02:12:46] ~~~^
# [02:12:46] SMILES Parse Error: Failed parsing SMILES 'NC1(CCC1=CON=C1CN=CC=NC=N1' for input: 'NC1(CCC1=CON=C1CN=CC=NC=N1'
# [02:12:46] SMILES Parse Error: unclosed ring for input: 'CC(O)C(O)C2CC1C2'
# [02:12:46] SMILES Parse Error: unclosed ring for input: 'CC1C2OC1CN1'
# [02:12:46] SMILES Parse Error: unclosed ring for input: 'CC(C#N)C12'
# [02:12:46] SMILES Parse Error: unclosed ring for input: 'OCC(=N)N1C'
# [02:12:46] SMILES Parse Error: unclosed ring for input: 'OC1C(=O)C23'
# [02:12:46] SMILES Parse Error: unclosed ring for input: 'CN1N=NN=C1C=CON=N1'
# [02:12:46] SMILES Parse Error: unclosed ring for input: 'NC(=N)OC(=N)N1'
# [02:12:46] SMILES Parse Error: unclosed ring for input: 'CNC1=NC(=O)C=C2'
# [02:12:46] SMILES Parse Error: unclosed ring for input: 'C1CC2=CN=CC2=O'
# [02:12:46] SMILES Parse Error: unclosed ring for input: 'CC12CC324'
# [02:12:46] Explicit valence for atom # 5 C, 5, is greater than permitted
# [02:12:46] SMILES Parse Error: unclosed ring for input: 'CCC1OC(C)C(=O)NC=O'
# [02:12:46] SMILES Parse Error: extra open parentheses while parsing: CC1(OC(=N)O1
# [02:12:46] SMILES Parse Error: check for mistakes around position 4:
# [02:12:46] CC1(OC(=N)O1
# [02:12:46] ~~~^
# [02:12:46] SMILES Parse Error: Failed parsing SMILES 'CC1(OC(=N)O1' for input: 'CC1(OC(=N)O1'
# [02:12:46] SMILES Parse Error: unclosed ring for input: 'C#CC1=C(C)COC=O'
# [02:12:46] SMILES Parse Error: unclosed ring for input: 'CCNC(=O)C12'
# [02:12:46] SMILES Parse Error: unclosed ring for input: 'CNC1=CC(C)=CC1(C)N2CC1C2'
# [02:12:46] SMILES Parse Error: unclosed ring for input: 'C1NC2C34'
# [02:12:46] SMILES Parse Error: unclosed ring for input: 'C1C2OC2C1(C#N)C2=O'
# [02:12:46] SMILES Parse Error: unclosed ring for input: 'OC12C3CC11OCC21'
# Total Samples: 500
# Valid Molecules: 263
# Validity Rate: 52.60%
# [02:12:46] SMILES Parse Error: unclosed ring for input: 'O=C1CC2C(C)O1'
# [02:12:47] SMILES Parse Error: unclosed ring for input: 'COC1C2C1C(C#N)C2CC1C2'

# %%
from rdkit.Chem import Draw

# Create the grid as a PNG image directly
img = Draw.MolsToGridImage(valid_molecules[:12], molsPerRow=4, subImgSize=(300,300))

if hasattr(img, 'data'):
    with open('generated_molecules.png', 'wb') as f:
        f.write(img.data)
    print("Saved using .data attribute!")
else:
    from rdkit.Chem.Draw import RdMolDrawing
    Draw.MolToFile(valid_molecules[0], 'single_molecule.png') # Test a single one
    print("Saved a single molecule to test.")
# Out:
# Saved using .data attribute!
